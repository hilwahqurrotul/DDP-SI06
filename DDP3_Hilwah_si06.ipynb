# %%
#Soal 1
Nama =  'Hilwah Qurrotul Aini'
Nim =  '0110124057'
Rombel =  'SI06'
No_Telp =  '628986673096'
Alamat =  'Bogor, Jawa Barat'

print (f'Nama saya adalah :  { Nama }  \n Nim saya :  { Nim }  \n Rombel saya :  { Rombel }  \n Nomer Telpon saya :  { No_Telp }  \n Saya tinggal di :  { Alamat } ' )
print ( ' ==================' )

#Soal 2
Nama =  'Meila Ayu Zahara'
Nim =  '0110124051'
Rombel =  'SI04'
No_Telp =  '6289503475436'
Alamat =  'Bogor, Jawa Barat'

print ( 'Nama teman saya :' ,  Nama )
print ( 'Nim teman saya :' ,  Nim )
print ( 'Rombel teman saya :' ,  Rombel )
print ( 'Nomer Telpon teman saya :' ,  No_Telp )
print ( 'Teman saya tinggal di :' ,  Alamat )
print ( '==================' )

#Soal 3
TB = int ( input ( 'Masukan tinggi badan :' ))
bb_ideal =  ( TB -  110 )  +  ( TB -  100 )  *  0.15

print ( 'berat badan ideal saya :' , bb_ideal )
print ( '===================' )

#Soal 4
Celcius = float ( input ( 'Masukan suhu celcius :' ))
Fahrenheit =  ( 9 / 5  * Celcius )  +  32

print (f'Hasil dari fahrenheit adalah : {Fahrenheit :.2f} ' )
print ( '===================' )

#Soal 5
#Luas tabung
jari_jari = float ( input ( 'Masukan jari jarinya :' ))
tinggi =  float ( input ( 'Masukan tingginya :' ))
luas_permukaan =  2 * 22/7 * jari_jari *  ( jari_jari+tinggi )
keliling_tabung = 2 * 22/7

print (f'Hasil dari luas tabung adalah : {luas_permukaan :.2f}' )
print (f'Hasil dari keliling tabung adalah : {keliling_tabung :.2f}' )
# Out:
# Nama saya adalah :  Hilwah Qurrotul Aini
#  Nim saya :  0110124057
#  Rombel saya :  SI06
#  Nomer Telpon saya :  628986673096
#  Saya tinggal di :  Bogor, Jawa Barat
# ...
# Nama teman saya : Meila Ayu Zahara
# Nim teman saya : 0110124051
# Rombel teman saya : SI04
# Nomer Telpon teman saya : 6289503475436
# Teman saya tinggal di : Bogor, Jawa Barat
# ...
# Masukan tinggi badan :155
# berat badan ideal saya : 53.25
# ...
# Masukan suhu celcius :18
# Hasil dari fahrenheit adalah : 64.40
# ...
# Masukan jari jarinya :20
# Masukan tingginya :30
# Hasil dari luas tabung adalah : 6285.71
# Hasil dari keliling tabung adalah : 6.29
